# %%
import pandas as pd

df = pd.read_csv('given_data/train.csv')
df[['heartbeat_signals1','heartbeat_signals2','heartbeat_signals3','heartbeat_signals4',
'heartbeat_signals5','heartbeat_signals6','heartbeat_signals7','heartbeat_signals8',
'heartbeat_signals9','heartbeat_signals10','heartbeat_signals11','heartbeat_signals12',
'heartbeat_signals13','heartbeat_signals14','heartbeat_signals15','heartbeat_signals16',
'heartbeat_signals17','heartbeat_signals18','heartbeat_signals19','heartbeat_signals20',
'heartbeat_signals21','heartbeat_signals22','heartbeat_signals23','heartbeat_signals24',
'heartbeat_signals25','heartbeat_signals26','heartbeat_signals27','heartbeat_signals28',
'heartbeat_signals29','heartbeat_signals30','heartbeat_signals31','heartbeat_signals32',
'heartbeat_signals33','heartbeat_signals34','heartbeat_signals35','heartbeat_signals36',
'heartbeat_signals37','heartbeat_signals38','heartbeat_signals39','heartbeat_signals40',
'heartbeat_signals41','heartbeat_signals42','heartbeat_signals43','heartbeat_signals44',
'heartbeat_signals45','heartbeat_signals46','heartbeat_signals47','heartbeat_signals48',
'heartbeat_signals49','heartbeat_signals50','heartbeat_signals51','heartbeat_signals52',
'heartbeat_signals53','heartbeat_signals54','heartbeat_signals55','heartbeat_signals56',
'heartbeat_signals57','heartbeat_signals58','heartbeat_signals59','heartbeat_signals60',
'heartbeat_signals61','heartbeat_signals62','heartbeat_signals63','heartbeat_signals64',
'heartbeat_signals65','heartbeat_signals66','heartbeat_signals67','heartbeat_signals68',
'heartbeat_signals69','heartbeat_signals70','heartbeat_signals71','heartbeat_signals72',
'heartbeat_signals73','heartbeat_signals74','heartbeat_signals75','heartbeat_signals76',
'heartbeat_signals77','heartbeat_signals78','heartbeat_signals79','heartbeat_signals80',
'heartbeat_signals81','heartbeat_signals82','heartbeat_signals83','heartbeat_signals84',
'heartbeat_signals85','heartbeat_signals86','heartbeat_signals87','heartbeat_signals88',
'heartbeat_signals89','heartbeat_signals90','heartbeat_signals91','heartbeat_signals92',
'heartbeat_signals93','heartbeat_signals94','heartbeat_signals95','heartbeat_signals96',
'heartbeat_signals97','heartbeat_signals98','heartbeat_signals99','heartbeat_signals100',
'heartbeat_signals101','heartbeat_signals102','heartbeat_signals103','heartbeat_signals104',
'heartbeat_signals105','heartbeat_signals106','heartbeat_signals107','heartbeat_signals108',
'heartbeat_signals109','heartbeat_signals110','heartbeat_signals111','heartbeat_signals112',
'heartbeat_signals113','heartbeat_signals114','heartbeat_signals115','heartbeat_signals116',
'heartbeat_signals117','heartbeat_signals118','heartbeat_signals119','heartbeat_signals120',
'heartbeat_signals121','heartbeat_signals122','heartbeat_signals123','heartbeat_signals124',
'heartbeat_signals125','heartbeat_signals126','heartbeat_signals127','heartbeat_signals128',
'heartbeat_signals129','heartbeat_signals130','heartbeat_signals131','heartbeat_signals132',
'heartbeat_signals133','heartbeat_signals134','heartbeat_signals135','heartbeat_signals136',
'heartbeat_signals137','heartbeat_signals138','heartbeat_signals139','heartbeat_signals140',
'heartbeat_signals141','heartbeat_signals142','heartbeat_signals143','heartbeat_signals144',
'heartbeat_signals145','heartbeat_signals146','heartbeat_signals147','heartbeat_signals148',
'heartbeat_signals149','heartbeat_signals150','heartbeat_signals151','heartbeat_signals152',
'heartbeat_signals153','heartbeat_signals154','heartbeat_signals155','heartbeat_signals156',
'heartbeat_signals157','heartbeat_signals158','heartbeat_signals159','heartbeat_signals160',
'heartbeat_signals161','heartbeat_signals162','heartbeat_signals163','heartbeat_signals164',
'heartbeat_signals165','heartbeat_signals166','heartbeat_signals167','heartbeat_signals168',
'heartbeat_signals169','heartbeat_signals170','heartbeat_signals171','heartbeat_signals172',
'heartbeat_signals173','heartbeat_signals174','heartbeat_signals175','heartbeat_signals176',
'heartbeat_signals177','heartbeat_signals178','heartbeat_signals179','heartbeat_signals180',
'heartbeat_signals181','heartbeat_signals182','heartbeat_signals183','heartbeat_signals184',
'heartbeat_signals185','heartbeat_signals186','heartbeat_signals187','heartbeat_signals188',
'heartbeat_signals189','heartbeat_signals190','heartbeat_signals191','heartbeat_signals192',
'heartbeat_signals193','heartbeat_signals194','heartbeat_signals195','heartbeat_signals196',
'heartbeat_signals197','heartbeat_signals198','heartbeat_signals199','heartbeat_signals200',
'heartbeat_signals201','heartbeat_signals202','heartbeat_signals203','heartbeat_signals204',
'heartbeat_signals205']] = df['heartbeat_signals'].str.split(',', expand=True)
df.drop(['heartbeat_signals'], axis=1, inplace=True)

df.to_csv('split_data/train.csv', index=False)
# Out:
# C:\Users\JOVIALN\AppData\Local\Temp\ipykernel_2284\3740355482.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[['heartbeat_signals1','heartbeat_signals2','heartbeat_signals3','heartbeat_signals4',
# C:\Users\JOVIALN\AppData\Local\Temp\ipykernel_2284\3740355482.py:4: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[['heartbeat_signals1','heartbeat_signals2','heartbeat_signals3','heartbeat_signals4',
# ...
